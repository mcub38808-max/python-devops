# %%
def manage_tags(existing_tags: dict, *simple_tags, **key_value_tags) -> dict:
    """
    Applies simple and key-value tags to an existing dictionary of tags.

    Args:
        existing_tags: The initial dictionary of tags.
        *simple_tags: Positional string arguments to be added as tags with a
                      value of 'true'. Duplicates should be ignored.
        **key_value_tags: Keyword arguments to be added or used to overwrite
                          existing tags.

    Returns:
        A new dictionary with all tags merged.
    """

    try:
        # TODO: Implement the tagging logic.
        # 1. Do not modify the original dictionary
        final_tags = existing_tags
        
        # 2. Process the 'simple_tags' (*args).
        unique_simple_tags = set(simple_tags)
        simple_tag_with_values = {k:'true' for k in unique_simple_tags}
        
        # 3. Process the 'key_value_tags' (**kwargs).
        final_tags = existing_tags | simple_tag_with_values | key_value_tags

    except TypeError as err:
        print(f"Existing tags {existing_tags} must be a dictionary")
        raise TypeError
        
    
    # 4. Return the new, merged dictionary.
    return final_tags

#initial = {'owner': 'dev-team', 'env': 'dev'}
initial = ['owner', 'dev']
final_tags = manage_tags(
    initial,
    'billable',              # A simple tag
    'critical',              # Another simple tag
    env='staging',           # A key-value tag that overwrites an existing key
    cost_center='xyz-123'    # A new key-value tag
)

print (final_tags)
# Out:
# Existing tags ['owner', 'dev'] must be a dictionary
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 26, in manage_tags(existing_tags, *simple_tags, **key_value_tags)
#      25     # 3. Process the 'key_value_tags' (**kwargs).
# ---> 26     final_tags = existing_tags | simple_tag_with_values | key_value_tags
#      28 except TypeError as err:
#
# TypeError: unsupported operand type(s) for |: 'list' and 'dict'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 38
#      36 #initial = {'owner': 'dev-team', 'env': 'dev'}
#      37 initial = ['owner', 'dev']
# ---> 38 final_tags = manage_tags(
#      39     initial,
#      40     'billable',              # A simple tag
#      41     'critical',              # Another simple tag
#      42     env='staging',           # A key-value tag that overwrites an existing key
#      43     cost_center='xyz-123'    # A new key-value tag
#      44 )
#      46 print (final_tags)
#
# Cell In[3], line 30, in manage_tags(existing_tags, *simple_tags, **key_value_tags)
#      28 except TypeError as err:
#      29     print(f"Existing tags {existing_tags} must be a dictionary")
# ---> 30     raise TypeError
#      33 # 4. Return the new, merged dictionary.
#      34 return final_tags
#
# TypeError:
