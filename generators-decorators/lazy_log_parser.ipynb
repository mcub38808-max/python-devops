# %%
pwd
# Out:
# '/home/mcub38808/mypyprojects/virtual-envs/python-devops/generators-decorators'

# %%
import json
def read_log_lines(filepath):
    """
    Creates a generator that reads a log file, yielding valid, non-comment lines.

    Args:
        filepath (str): The path to the log file.

    Yields:
        str: A stripped, non-empty, non-comment line from the file.
    """
    # TODO: Implement the generator logic.
    # 1. Open the file safely.
    # 2. Iterate through each line, removing whitespace and checking whether it's valid.
    # 3. If the line is valid, yield it.
    with open(filepath, 'r') as file:
        for line in file:
            stripped_line = line.strip()
            if not stripped_line or stripped_line.startswith('#'):
                continue
            yield json.loads(stripped_line)

log_reader = read_log_lines('large_logs.txt') 

next(log_reader)
type(next(log_reader))
# Out:
# dict

# %%
next(log_reader)
# Out:
# {'ts': '2025-05-01 19:00:00+00:00',
#  'level': 'INFO',
#  'message': 'File file_1.dat processed successfully'}

# %%
next(log_reader)
# Out:
# {'ts': '2025-05-01 19:00:00+00:00',
#  'level': 'WARNING',
#  'message': 'Connection to host5.example.com timed out'}

# %%
next(log_reader)
# Out:
# {'ts': '2025-05-01 19:00:01+00:00',
#  'level': 'ERROR',
#  'message': 'Database transaction tx5376 rolled back'}
